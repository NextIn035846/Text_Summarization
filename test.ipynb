# %%
pip install -r requirements.txt
# Out:
# ...
# Obtaining file:///T:/Text_Summarization/Text_Summarization (from -r requirements.txt (line 21))
# ...
#   Using cached ensure-1.0.2-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached fastapi-0.78.0-py3-none-any.whl (54 kB)
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#   Using cached python_box-6.0.2-cp38-cp38-win_amd64.whl (944 kB)
# ...
#   Using cached uvicorn-0.18.3-py3-none-any.whl (57 kB)
# ...
#   Using cached starlette-0.19.1-py3-none-any.whl (63 kB)
# ...
#   Using cached anyio-4.1.0-py3-none-any.whl (83 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#   Using cached exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...
#   Using cached MarkupSafe-2.1.3-cp38-cp38-win_amd64.whl (17 kB)
# ...
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# ...
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# ...
#   Using cached datasets-2.15.0-py3-none-any.whl (521 kB)
# ...

# %%
def get_product(X:int,y:int) -> int:
    return X*y

# %% [markdown]
# In above fucation we pass the the integer and return it in int value but this fucation still work when we pass the string values

# %%
get_product(4,8)
# Out:
# 32

# %%
get_product(4,'9')
# Out:
# '9999'

# %%
from ensure
